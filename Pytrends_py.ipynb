# %% [markdown]
# <a href="https://colab.research.google.com/github/JinMerc/pytrends/blob/main/Pytrends_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# installation

# %%
# !pip install pytrends
# Out:
# ...
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=2dc6ce11aa6fa036468585ae5d6522ee1ca42a19191958ad97f47c9711969e10
#   Stored in directory: /root/.cache/pip/wheels/07/6f/5c/8174f98dec1bfbc7d5da4092854afcbcff4b26c3d9b66b5183
# Successfully built pytrends
# ...

# %% [markdown]
# `implementation [connecting to google]`

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %% [markdown]
# `Daily search trends`

# %%
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='india')
df.head()
# Out:
#                             0
# 0     Mallorca vs Real Madrid
# 1  Crystal Palace Vs Man City
# 2         NDA admit card 2022
# 3                     Rihanna
# 4                         PSG

# %% [markdown]
# `Realtime Search trends`

# %%
df1=pytrend.realtime_trending_searches(pn='IN')
df1.head()
# Out:
# array([['High Court of Karnataka, Hijab, India',
#         list(['High Court of Karnataka', 'Hijab', 'India'])],
#        ['High Court of Karnataka, TV9 Kannada, TV9, High Court, News18 Kannada',
#         list(['High Court of Karnataka', 'TV9 Kannada', 'TV9', 'High Court', 'News18 Kannada'])],
#        ['Ruchi Soya, Crore, Patanjali Ayurved, Stock, March',
#         list(['Ruchi Soya', 'Crore', 'Patanjali Ayurved', 'Stock', 'March'])],
#        ['India Meteorological Department, Heat wave, Mumbai',
#         list(['India Meteorological Department', 'Heat wave', 'Mumbai'])],
#        ['United Arab Emirates national cricket team, Papua New Guinea national cricket team, Dream11, International Cricket Council',
#         list(['United Arab Emirates national cricket team', 'Papua New Guinea national cricket team', 'Dream11', 'International Cricket Council'])],
#        ['Stephen Curry, Golden State Warriors, Draymond Green, NBA',
# ...
